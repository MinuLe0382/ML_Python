# %% [markdown]
# # **5.10 House_Prices**

# %% [markdown]
# ### **Overview**
# **1. Feature Engineering**
#     - Log Transform
#     - Outlier
#
# **2. Linear Regression**
#
# **3. Regression Tree**
#
# **4. Mixed Model & Stacking Model**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 데이터를 보아하니 숫자데이터 보다는 카테고리 데이터가 많아보인다.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

house_df_org = pd.read_csv('house_price.csv')
house_df = house_df_org.copy()
house_df.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %% [markdown]
# **1stFlrSF**: First Floor square feet
# **2ndFlrSF**: Second floor square feet
# **GrLivArea**: Above grade (ground) living area square feet
# **Bedroom**: Bedrooms above grade (does NOT include basement bedrooms)
# **LotArea**: Lot size in square feet
# **GarageArea**: Size of garage in square feet
# **OverallQual**: Rates the overall material and finish of the house
# 10: Very Excellent
# 9: Excellent
# 8: Very Good
# 7: Good
# 6: Above Average
# 5: Average
# 4: Below Average
# 3: Fair
# 2: Poor
# 1: Very Poor
#
# **OverallCond**: Rates the overall condition of the house
# 10: Very Excellent
# 9: Excellent
# 8: Very Good
# 7: Good
# 6: Above Average
# 5: Average
# 4: Below Average
# 3: Fair
# 2: Poor
# 1: Very Poor
#
# **YearBuilt**: Original construction date
# **Neighborhood**: Physical locations within Ames city limits
# **Blmngtn**: Bloomington Heights
# **Bluestem**: Bluestem
# **BrDale**: Briardale

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
print('Shape of Datasets: ', house_df.shape)
print('\nType of all Features \n', house_df.dtypes.value_counts())
isnull_series = house_df.isnull().sum()
print('\nNull Columns:\n', isnull_series[isnull_series > 0].sort_values(ascending=False))
# Out:
# Shape of Datasets:  (1460, 81)
#
# Type of all Features
#  object     43
# int64      35
# float64     3
# Name: count, dtype: int64
#
# Null Columns:
#  PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %% [markdown]
# ### **Distribution of Target SalePrice**

# %%
plt.title('Original Sale Price Histogram')
plt.xticks(rotation=15)
sns.histplot(house_df['SalePrice'], kde=True)
plt.show()

# %% [markdown]
# ### **Log Transform for Target SalePrice**

# %%
plt.title('Log Transformed Sale Price Histogram')
log_SalePrice = np.log1p(house_df['SalePrice'])
sns.histplot(log_SalePrice, kde=True)
plt.show()

# %%
# SalePrice 로그 변환
original_SalePrice = house_df['SalePrice']
house_df['SalePrice'] = np.log1p(house_df['SalePrice'])

# Null 이 너무 많은 컬럼들과 불필요한 컬럼 삭제
house_df.drop(['Id','PoolQC' , 'MiscFeature', 'Alley', 'Fence','FireplaceQu', 'MasVnrType'], axis=1 , inplace=True)
# 판다스 버전업으로 인하여 더이상 mean()을 직접 적용하는 것은 불가능
'''
# object가 아닌 number 타입을 별도 리스트로 추출
num_columns = house_df.dtypes[house_df.dtypes != 'object'].index.to_list()
# number 타입 컬럼들에 대해서 Null컬럼들은 평균값으로 대체
house_df[num_columns].fillna(house_df[num_columns].mean(),inplace=True)
'''
# object 타입이 아닌 number 타입을 별도 리스트로 추출
num_columns = house_df.select_dtypes(include=['number']).columns

# number 타입 컬럼들에 대해서 Null컬럼들은 평균값으로 대체
house_df[num_columns] = house_df[num_columns].fillna(house_df[num_columns].mean())

# Null 값이 있는 피처명과 타입을 추출 (숫자형 NULL은 해결되었음)
null_column_count = house_df.isnull().sum()[house_df.isnull().sum() > 0]
print('## Null 피처의 Type :\n', house_df.dtypes[null_column_count.index])
# Out:
# ## Null 피처의 Type :
#  BsmtQual        object
# BsmtCond        object
# BsmtExposure    object
# BsmtFinType1    object
# BsmtFinType2    object
# Electrical      object
# GarageType      object
# GarageFinish    object
# GarageQual      object
# GarageCond      object
# dtype: object

# %%
num_columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
null_column_count
# Out:
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %% [markdown]
# ### **Object One Hot Encoding by get_dummies()**

# %% [markdown]
# get_dummies()는 null값을 반영하여 자동으로 인코딩을 수행한다

# %%
s1 = ['a', 'b', np.nan]
pd.get_dummies(s1, dummy_na=False)
# null 값은 모두 0임
# Out:
#        a      b
# 0   True  False
# 1  False   True
# 2  False  False

# %%
s2 = ['a', 'b', np.nan]
pd.get_dummies(s2, dummy_na=True)
# 새로운 Column을 부여
# Out:
#        a      b    NaN
# 0   True  False  False
# 1  False   True  False
# 2  False  False   True

# %%
print('get_dummies() 수행 전 데이터 Shape:', house_df.shape)
house_df_ohe = pd.get_dummies(house_df)
print('get_dummies() 수행 후 데이터 Shape:', house_df_ohe.shape)

null_column_count = house_df_ohe.isnull().sum()[house_df_ohe.isnull().sum() > 0]
print('## Null 피처의 Type :\n', house_df_ohe.dtypes[null_column_count.index])
# Out:
# get_dummies() 수행 전 데이터 Shape: (1460, 74)
# get_dummies() 수행 후 데이터 Shape: (1460, 267)
# ## Null 피처의 Type :
#  Series([], dtype: object)

# %%
pd.set_option('display.max_columns', 300)
house_df_ohe.head(5)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710             1             0
# 1      1262         0             0       1262             0             1
# 2       920       866             0       1786             1             0
# 3       961       756             0       1717             1             0
# 4      1145      1053             0       2198             1             0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         2         1             3             1             8           0
# 1         2         0             3             1             6           1
# 2         2         1             3             1             6           1
# 3         1         0             3             1             7           1
# 4         2         1             4             1             9           1
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0       2003.0           2         548           0           61
# 1       1976.0           2         460         298            0
# 2       2001.0           2         608           0           42
# 3       1998.0           3         642           0           35
# 4       2000.0           3         836         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice  MSZoning_C (all)  MSZoning_FV  MSZoning_RH  MSZoning_RL  \
# 0  12.247699             False        False        False         True
# 1  12.109016             False        False        False         True
# 2  12.317171             False        False        False         True
# 3  11.849405             False        False        False         True
# 4  12.429220             False        False        False         True
#
#    MSZoning_RM  Street_Grvl  Street_Pave  LotShape_IR1  LotShape_IR2  \
# 0        False        False         True         False         False
# 1        False        False         True         False         False
# 2        False        False         True          True         False
# 3        False        False         True          True         False
# 4        False        False         True          True         False
#
#    LotShape_IR3  LotShape_Reg  LandContour_Bnk  LandContour_HLS  \
# 0         False          True            False            False
# 1         False          True            False            False
# 2         False         False            False            False
# 3         False         False            False            False
# 4         False         False            False            False
#
#    LandContour_Low  LandContour_Lvl  Utilities_AllPub  Utilities_NoSeWa  \
# 0            False             True              True             False
# 1            False             True              True             False
# 2            False             True              True             False
# 3            False             True              True             False
# 4            False             True              True             False
#
#    LotConfig_Corner  LotConfig_CulDSac  LotConfig_FR2  LotConfig_FR3  \
# 0             False              False          False          False
# 1             False              False           True          False
# 2             False              False          False          False
# 3              True              False          False          False
# 4             False              False           True          False
#
#    LotConfig_Inside  LandSlope_Gtl  LandSlope_Mod  LandSlope_Sev  \
# 0              True           True          False          False
# 1             False           True          False          False
# 2              True           True          False          False
# 3             False           True          False          False
# 4             False           True          False          False
#
#    Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 0                 False                 False                  True
# 1                 False                 False                 False
# 2                 False                 False                  True
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                  True                 False                 False
# 4                 False                 False                 False
#
#    Neighborhood_IDOTRR  Neighborhood_MeadowV  Neighborhood_Mitchel  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_NAmes  Neighborhood_NPkVill  Neighborhood_NWAmes  \
# 0               False                 False                False
# 1               False                 False                False
# 2               False                 False                False
# 3               False                 False                False
# 4               False                 False                False
#
#    Neighborhood_NoRidge  Neighborhood_NridgHt  Neighborhood_OldTown  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                  True                 False                 False
#
#    Neighborhood_SWISU  Neighborhood_Sawyer  Neighborhood_SawyerW  \
# 0               False                False                 False
# 1               False                False                 False
# 2               False                False                 False
# 3               False                False                 False
# 4               False                False                 False
#
#    Neighborhood_Somerst  Neighborhood_StoneBr  Neighborhood_Timber  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    Neighborhood_Veenker  Condition1_Artery  Condition1_Feedr  Condition1_Norm  \
# 0                 False              False             False             True
# 1                  True              False              True            False
# 2                 False              False             False             True
# 3                 False              False             False             True
# 4                 False              False             False             True
#
#    Condition1_PosA  Condition1_PosN  Condition1_RRAe  Condition1_RRAn  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Condition1_RRNe  Condition1_RRNn  Condition2_Artery  Condition2_Feedr  \
# 0            False            False              False             False
# 1            False            False              False             False
# 2            False            False              False             False
# 3            False            False              False             False
# 4            False            False              False             False
#
#    Condition2_Norm  Condition2_PosA  Condition2_PosN  Condition2_RRAe  \
# 0             True            False            False            False
# 1             True            False            False            False
# 2             True            False            False            False
# 3             True            False            False            False
# 4             True            False            False            False
#
#    Condition2_RRAn  Condition2_RRNn  BldgType_1Fam  BldgType_2fmCon  \
# 0            False            False           True            False
# 1            False            False           True            False
# 2            False            False           True            False
# 3            False            False           True            False
# 4            False            False           True            False
#
#    BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  HouseStyle_1.5Fin  \
# 0            False           False            False              False
# 1            False           False            False              False
# 2            False           False            False              False
# 3            False           False            False              False
# 4            False           False            False              False
#
#    HouseStyle_1.5Unf  HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  \
# 0              False              False              False              False
# 1              False               True              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Flat  \
# 0               True              False            False           False
# 1              False              False            False           False
# 2               True              False            False           False
# 3               True              False            False           False
# 4               True              False            False           False
#
#    RoofStyle_Gable  RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  \
# 0             True              False          False              False
# 1             True              False          False              False
# 2             True              False          False              False
# 3             True              False          False              False
# 4             True              False          False              False
#
#    RoofStyle_Shed  RoofMatl_ClyTile  RoofMatl_CompShg  RoofMatl_Membran  \
# 0           False             False              True             False
# 1           False             False              True             False
# 2           False             False              True             False
# 3           False             False              True             False
# 4           False             False              True             False
#
#    RoofMatl_Metal  RoofMatl_Roll  RoofMatl_Tar&Grv  RoofMatl_WdShake  \
# 0           False          False             False             False
# 1           False          False             False             False
# 2           False          False             False             False
# 3           False          False             False             False
# 4           False          False             False             False
#
#    RoofMatl_WdShngl  Exterior1st_AsbShng  Exterior1st_AsphShn  \
# 0             False                False                False
# 1             False                False                False
# 2             False                False                False
# 3             False                False                False
# 4             False                False                False
#
#    Exterior1st_BrkComm  Exterior1st_BrkFace  Exterior1st_CBlock  \
# 0                False                False               False
# 1                False                False               False
# 2                False                False               False
# 3                False                False               False
# 4                False                False               False
#
#    Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 0                False                False              False
# 1                 True                False              False
# 2                False                False              False
# 3                False                False              False
# 4                False                False              False
#
#    Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 0               False                 True                False
# 1               False                False                False
# 2               False                 True                False
# 3               False                False                 True
# 4               False                 True                False
#
#    Exterior1st_WdShing  Exterior2nd_AsbShng  Exterior2nd_AsphShn  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_Brk Cmn  Exterior2nd_BrkFace  Exterior2nd_CBlock  \
# 0                False                False               False
# 1                False                False               False
# 2                False                False               False
# 3                False                False               False
# 4                False                False               False
#
#    Exterior2nd_CmentBd  Exterior2nd_HdBoard  Exterior2nd_ImStucc  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_MetalSd  Exterior2nd_Other  Exterior2nd_Plywood  \
# 0                False              False                False
# 1                 True              False                False
# 2                False              False                False
# 3                False              False                False
# 4                False              False                False
#
#    Exterior2nd_Stone  Exterior2nd_Stucco  Exterior2nd_VinylSd  \
# 0              False               False                 True
# 1              False               False                False
# 2              False               False                 True
# 3              False               False                False
# 4              False               False                 True
#
#    Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  ExterQual_Ex  ExterQual_Fa  \
# 0                False                False         False         False
# 1                False                False         False         False
# 2                False                False         False         False
# 3                False                 True         False         False
# 4                False                False         False         False
#
#    ExterQual_Gd  ExterQual_TA  ExterCond_Ex  ExterCond_Fa  ExterCond_Gd  \
# 0          True         False         False         False         False
# 1         False          True         False         False         False
# 2          True         False         False         False         False
# 3         False          True         False         False         False
# 4          True         False         False         False         False
#
#    ExterCond_Po  ExterCond_TA  Foundation_BrkTil  Foundation_CBlock  \
# 0         False          True              False              False
# 1         False          True              False               True
# 2         False          True              False              False
# 3         False          True               True              False
# 4         False          True              False              False
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# 0              True            False             False            False
# 1             False            False             False            False
# 2              True            False             False            False
# 3             False            False             False            False
# 4              True            False             False            False
#
#    BsmtQual_Ex  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_TA  BsmtCond_Fa  \
# 0        False        False         True        False        False
# 1        False        False         True        False        False
# 2        False        False         True        False        False
# 3        False        False        False         True        False
# 4        False        False         True        False        False
#
#    BsmtCond_Gd  BsmtCond_Po  BsmtCond_TA  BsmtExposure_Av  BsmtExposure_Gd  \
# 0        False        False         True            False            False
# 1        False        False         True            False             True
# 2        False        False         True            False            False
# 3         True        False        False            False            False
# 4        False        False         True             True            False
#
#    BsmtExposure_Mn  BsmtExposure_No  BsmtFinType1_ALQ  BsmtFinType1_BLQ  \
# 0            False             True             False             False
# 1            False            False              True             False
# 2             True            False             False             False
# 3            False             True              True             False
# 4            False            False             False             False
#
#    BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_Rec  BsmtFinType1_Unf  \
# 0              True             False             False             False
# 1             False             False             False             False
# 2              True             False             False             False
# 3             False             False             False             False
# 4              True             False             False             False
#
#    BsmtFinType2_ALQ  BsmtFinType2_BLQ  BsmtFinType2_GLQ  BsmtFinType2_LwQ  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_Floor  Heating_GasA  \
# 0             False              True          False          True
# 1             False              True          False          True
# 2             False              True          False          True
# 3             False              True          False          True
# 4             False              True          False          True
#
#    Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  HeatingQC_Ex  \
# 0         False         False         False         False          True
# 1         False         False         False         False          True
# 2         False         False         False         False          True
# 3         False         False         False         False         False
# 4         False         False         False         False          True
#
#    HeatingQC_Fa  HeatingQC_Gd  HeatingQC_Po  HeatingQC_TA  CentralAir_N  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False          True         False         False         False
# 4         False         False         False         False         False
#
#    CentralAir_Y  Electrical_FuseA  Electrical_FuseF  Electrical_FuseP  \
# 0          True             False             False             False
# 1          True             False             False             False
# 2          True             False             False             False
# 3          True             False             False             False
# 4          True             False             False             False
#
#    Electrical_Mix  Electrical_SBrkr  KitchenQual_Ex  KitchenQual_Fa  \
# 0           False              True           False           False
# 1           False              True           False           False
# 2           False              True           False           False
# 3           False              True           False           False
# 4           False              True           False           False
#
#    KitchenQual_Gd  KitchenQual_TA  Functional_Maj1  Functional_Maj2  \
# 0            True           False            False            False
# 1           False            True            False            False
# 2            True           False            False            False
# 3            True           False            False            False
# 4            True           False            False            False
#
#    Functional_Min1  Functional_Min2  Functional_Mod  Functional_Sev  \
# 0            False            False           False           False
# 1            False            False           False           False
# 2            False            False           False           False
# 3            False            False           False           False
# 4            False            False           False           False
#
#    Functional_Typ  GarageType_2Types  GarageType_Attchd  GarageType_Basment  \
# 0            True              False               True               False
# 1            True              False               True               False
# 2            True              False               True               False
# 3            True              False              False               False
# 4            True              False               True               False
#
#    GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
# 3               False               False               True
# 4               False               False              False
#
#    GarageFinish_Fin  GarageFinish_RFn  GarageFinish_Unf  GarageQual_Ex  \
# 0             False              True             False          False
# 1             False              True             False          False
# 2             False              True             False          False
# 3             False             False              True          False
# 4             False              True             False          False
#
#    GarageQual_Fa  GarageQual_Gd  GarageQual_Po  GarageQual_TA  GarageCond_Ex  \
# 0          False          False          False           True          False
# 1          False          False          False           True          False
# 2          False          False          False           True          False
# 3          False          False          False           True          False
# 4          False          False          False           True          False
#
#    GarageCond_Fa  GarageCond_Gd  GarageCond_Po  GarageCond_TA  PavedDrive_N  \
# 0          False          False          False           True         False
# 1          False          False          False           True         False
# 2          False          False          False           True         False
# 3          False          False          False           True         False
# 4          False          False          False           True         False
#
#    PavedDrive_P  PavedDrive_Y  SaleType_COD  SaleType_CWD  SaleType_Con  \
# 0         False          True         False         False         False
# 1         False          True         False         False         False
# 2         False          True         False         False         False
# 3         False          True         False         False         False
# 4         False          True         False         False         False
#
#    SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0           False           False           False         False         False
# 1           False           False           False         False         False
# 2           False           False           False         False         False
# 3           False           False           False         False         False
# 4           False           False           False         False         False
#
#    SaleType_WD  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# 0         True                  False                  False
# 1         True                  False                  False
# 2         True                  False                  False
# 3         True                   True                  False
# 4         True                  False                  False
#
#    SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 0                 False                 False                  True
# 1                 False                 False                  True
# 2                 False                 False                  True
# 3                 False                 False                 False
# 4                 False                 False                  True
#
#    SaleCondition_Partial
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %% [markdown]
# ### **Lineae Regression Model Train/Predict/Evaluation**

# %%
def get_rmse(model):
    pred = model.predict(X_test)
    mse = mean_squared_error(y_test , pred)
    rmse = np.sqrt(mse)
    print('{0} 로그 변환된 RMSE: {1}'.format(model.__class__.__name__,np.round(rmse, 3)))
    return rmse

def get_rmses(models):
    rmses = [ ]
    for model in models:
        rmse = get_rmse(model)
        rmses.append(rmse)
    return rmses

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

y_target = house_df_ohe['SalePrice']
X_features = house_df_ohe.drop('SalePrice',axis=1, inplace=False)

X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.2, random_state=156)

# LinearRegression, Ridge, Lasso 학습, 예측, 평가
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)

ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)

lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)

models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)
# Out:
# LinearRegression 로그 변환된 RMSE: 0.132
# Ridge 로그 변환된 RMSE: 0.127
# Lasso 로그 변환된 RMSE: 0.176
# [0.13170346544396727, 0.12743057784210568, 0.17628250556471403]

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 700           20    85.000000    14331            8            5       2002
# 401           20    65.000000     8767            7            5       2005
# 582           90    81.000000    11841            6            5       1990
# 376           85    57.000000     8846            5            5       1996
# 271           20    73.000000    39104            7            7       1954
# ...          ...          ...      ...          ...          ...        ...
# 849           80    80.000000     9600            6            7       1976
# 1034          30    50.000000     6305            5            7       1938
# 811          120    70.049958     4438            6            5       2004
# 1442          60    85.000000    11003           10            5       2008
# 716           70    60.000000    10800            7            8       1890
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 700           2002       630.0        1274           0        526
# 401           2005         0.0          24           0       1286
# 582           1990       104.0         816           0          0
# 376           1996         0.0         298           0        572
# 271           2005         0.0         226        1063         96
# ...            ...         ...         ...         ...        ...
# 849           1994       360.0           0           0        528
# 1034          1950         0.0           0           0        920
# 811           2004       169.0         662           0        186
# 1442          2008       160.0         765           0        252
# 716           1998         0.0           0           0        718
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 700          1800      1800         0             0       1800             1
# 401          1310      1310         0             0       1310             0
# 582           816       816         0             0        816             1
# 376           870       914         0             0        914             0
# 271          1385      1363         0             0       1363             1
# ...           ...       ...       ...           ...        ...           ...
# 849           528      1094       761             0       1855             0
# 1034          920       954         0             0        954             0
# 811           848       848         0             0        848             1
# 1442         1017      1026       981             0       2007             1
# 716           718      1576       978             0       2554             0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 700              0         2         0             3             1
# 401              0         2         0             3             1
# 582              0         1         0             3             1
# 376              0         1         0             2             1
# 271              0         1         0             2             1
# ...            ...       ...       ...           ...           ...
# 849              0         2         1             3             1
# 1034             0         1         0             2             1
# 811              0         1         0             1             1
# 1442             0         2         1             3             1
# 716              0         1         1             3             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# 700              7           1  2002.000000           3         765
# 401              6           1  2005.000000           2         400
# 582              5           0  1978.506164           0           0
# 376              5           0  1998.000000           2         576
# 271              5           2  1954.000000           2         439
# ...            ...         ...          ...         ...         ...
# 849              7           1  1976.000000           2         512
# 1034             5           1  1938.000000           1         240
# 811              4           1  2004.000000           2         420
# 1442            10           1  2008.000000           3         812
# 716              8           0  1996.000000           2         704
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 700          270           78              0          0            0
# 401            0            0              0          0            0
# 582            0           32              0          0            0
# 376            0            0              0          0            0
# 271           81            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 849          113          100              0          0            0
# 1034           0            0              0          0            0
# 811          140            0              0          0            0
# 1442         168           52              0          0            0
# 716            0           48            143          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold  MSZoning_C (all)  MSZoning_FV  \
# 700          0        0       5    2006             False        False
# 401          0        0       7    2006             False        False
# 582          0        0       5    2007             False        False
# 376          0        0       7    2006             False        False
# 271          0        0       4    2008             False        False
# ...        ...      ...     ...     ...               ...          ...
# 849          0        0       8    2007             False        False
# 1034         0        0       6    2007             False        False
# 811          0        0       6    2008             False        False
# 1442         0        0       4    2009             False         True
# 716          0        0       7    2007             False        False
#
#       MSZoning_RH  MSZoning_RL  MSZoning_RM  Street_Grvl  Street_Pave  \
# 700         False         True        False        False         True
# 401         False         True        False        False         True
# 582         False         True        False         True        False
# 376         False         True        False        False         True
# 271         False         True        False        False         True
# ...           ...          ...          ...          ...          ...
# 849         False         True        False        False         True
# 1034        False         True        False        False         True
# 811         False        False         True        False         True
# 1442        False        False        False        False         True
# 716         False        False         True        False         True
#
#       LotShape_IR1  LotShape_IR2  LotShape_IR3  LotShape_Reg  LandContour_Bnk  \
# 700          False         False         False          True            False
# 401           True         False         False         False            False
# 582          False         False         False          True            False
# 376           True         False         False         False            False
# 271           True         False         False         False            False
# ...            ...           ...           ...           ...              ...
# 849          False         False         False          True            False
# 1034         False         False         False          True             True
# 811          False         False         False          True            False
# 1442         False         False         False          True            False
# 716          False         False         False          True             True
#
#       LandContour_HLS  LandContour_Low  LandContour_Lvl  Utilities_AllPub  \
# 700             False            False             True              True
# 401             False            False             True              True
# 582             False            False             True              True
# 376             False            False             True              True
# 271             False             True            False              True
# ...               ...              ...              ...               ...
# 849             False            False             True              True
# 1034            False            False            False              True
# 811             False            False             True              True
# 1442            False            False             True              True
# 716             False            False            False              True
#
#       Utilities_NoSeWa  LotConfig_Corner  LotConfig_CulDSac  LotConfig_FR2  \
# 700              False             False              False          False
# 401              False             False              False          False
# 582              False             False              False          False
# 376              False             False               True          False
# 271              False             False               True          False
# ...                ...               ...                ...            ...
# 849              False             False              False           True
# 1034             False             False              False          False
# 811              False             False              False          False
# 1442             False             False              False          False
# 716              False             False              False          False
#
#       LotConfig_FR3  LotConfig_Inside  LandSlope_Gtl  LandSlope_Mod  \
# 700           False              True           True          False
# 401           False              True           True          False
# 582           False              True           True          False
# 376           False             False           True          False
# 271           False             False          False          False
# ...             ...               ...            ...            ...
# 849           False             False           True          False
# 1034          False              True           True          False
# 811           False              True           True          False
# 1442          False              True           True          False
# 716           False              True           True          False
#
#       LandSlope_Sev  Neighborhood_Blmngtn  Neighborhood_Blueste  \
# 700           False                 False                 False
# 401           False                 False                 False
# 582           False                 False                 False
# 376           False                 False                 False
# 271            True                 False                 False
# ...             ...                   ...                   ...
# 849           False                 False                 False
# 1034          False                 False                 False
# 811           False                 False                 False
# 1442          False                 False                 False
# 716           False                 False                 False
#
#       Neighborhood_BrDale  Neighborhood_BrkSide  Neighborhood_ClearCr  \
# 700                 False                 False                 False
# 401                 False                 False                 False
# 582                 False                 False                 False
# 376                 False                 False                 False
# 271                 False                 False                  True
# ...                   ...                   ...                   ...
# 849                 False                 False                 False
# 1034                False                 False                 False
# 811                 False                 False                 False
# 1442                False                 False                 False
# 716                 False                 False                 False
#
#       Neighborhood_CollgCr  Neighborhood_Crawfor  Neighborhood_Edwards  \
# 700                  False                 False                 False
# 401                   True                 False                 False
# 582                  False                 False                  True
# 376                   True                 False                 False
# 271                  False                 False                 False
# ...                    ...                   ...                   ...
# 849                  False                 False                 False
# 1034                 False                  True                 False
# 811                   True                 False                 False
# 1442                 False                 False                 False
# 716                  False                 False                 False
#
#       Neighborhood_Gilbert  Neighborhood_IDOTRR  Neighborhood_MeadowV  \
# 700                  False                False                 False
# 401                  False                False                 False
# 582                  False                False                 False
# 376                  False                False                 False
# 271                  False                False                 False
# ...                    ...                  ...                   ...
# 849                  False                False                 False
# 1034                 False                False                 False
# 811                  False                False                 False
# 1442                 False                False                 False
# 716                  False                False                 False
#
#       Neighborhood_Mitchel  Neighborhood_NAmes  Neighborhood_NPkVill  \
# 700                  False               False                 False
# 401                  False               False                 False
# 582                  False               False                 False
# 376                  False               False                 False
# 271                  False               False                 False
# ...                    ...                 ...                   ...
# 849                  False               False                 False
# 1034                 False               False                 False
# 811                  False               False                 False
# 1442                 False               False                 False
# 716                  False               False                 False
#
#       Neighborhood_NWAmes  Neighborhood_NoRidge  Neighborhood_NridgHt  \
# 700                 False                 False                 False
# 401                 False                 False                 False
# 582                 False                 False                 False
# 376                 False                 False                 False
# 271                 False                 False                 False
# ...                   ...                   ...                   ...
# 849                 False                 False                 False
# 1034                False                 False                 False
# 811                 False                 False                 False
# 1442                False                 False                 False
# 716                 False                 False                 False
#
#       Neighborhood_OldTown  Neighborhood_SWISU  Neighborhood_Sawyer  \
# 700                  False               False                False
# 401                  False               False                False
# 582                  False               False                False
# 376                  False               False                False
# 271                  False               False                False
# ...                    ...                 ...                  ...
# 849                  False               False                False
# 1034                 False               False                False
# 811                  False               False                False
# 1442                 False               False                False
# 716                   True               False                False
#
#       Neighborhood_SawyerW  Neighborhood_Somerst  Neighborhood_StoneBr  \
# 700                  False                 False                 False
# 401                  False                 False                 False
# 582                  False                 False                 False
# 376                  False                 False                 False
# 271                  False                 False                 False
# ...                    ...                   ...                   ...
# 849                  False                 False                 False
# 1034                 False                 False                 False
# 811                  False                 False                 False
# 1442                 False                  True                 False
# 716                  False                 False                 False
#
#       Neighborhood_Timber  Neighborhood_Veenker  Condition1_Artery  \
# 700                  True                 False              False
# 401                 False                 False              False
# 582                 False                 False              False
# 376                 False                 False              False
# 271                 False                 False              False
# ...                   ...                   ...                ...
# 849                 False                  True              False
# 1034                False                 False              False
# 811                 False                 False              False
# 1442                False                 False              False
# 716                 False                 False              False
#
#       Condition1_Feedr  Condition1_Norm  Condition1_PosA  Condition1_PosN  \
# 700              False             True            False            False
# 401              False             True            False            False
# 582              False             True            False            False
# 376              False             True            False            False
# 271              False             True            False            False
# ...                ...              ...              ...              ...
# 849               True            False            False            False
# 1034             False             True            False            False
# 811              False             True            False            False
# 1442             False             True            False            False
# 716              False             True            False            False
#
#       Condition1_RRAe  Condition1_RRAn  Condition1_RRNe  Condition1_RRNn  \
# 700             False            False            False            False
# 401             False            False            False            False
# 582             False            False            False            False
# 376             False            False            False            False
# 271             False            False            False            False
# ...               ...              ...              ...              ...
# 849             False            False            False            False
# 1034            False            False            False            False
# 811             False            False            False            False
# 1442            False            False            False            False
# 716             False            False            False            False
#
#       Condition2_Artery  Condition2_Feedr  Condition2_Norm  Condition2_PosA  \
# 700               False             False             True            False
# 401               False             False             True            False
# 582               False             False             True            False
# 376               False             False             True            False
# 271               False             False             True            False
# ...                 ...               ...              ...              ...
# 849               False             False             True            False
# 1034              False             False             True            False
# 811               False             False             True            False
# 1442              False             False             True            False
# 716               False             False             True            False
#
#       Condition2_PosN  Condition2_RRAe  Condition2_RRAn  Condition2_RRNn  \
# 700             False            False            False            False
# 401             False            False            False            False
# 582             False            False            False            False
# 376             False            False            False            False
# 271             False            False            False            False
# ...               ...              ...              ...              ...
# 849             False            False            False            False
# 1034            False            False            False            False
# 811             False            False            False            False
# 1442            False            False            False            False
# 716             False            False            False            False
#
#       BldgType_1Fam  BldgType_2fmCon  BldgType_Duplex  BldgType_Twnhs  \
# 700            True            False            False           False
# 401            True            False            False           False
# 582           False            False             True           False
# 376            True            False            False           False
# 271            True            False            False           False
# ...             ...              ...              ...             ...
# 849            True            False            False           False
# 1034           True            False            False           False
# 811           False            False            False           False
# 1442           True            False            False           False
# 716            True            False            False           False
#
#       BldgType_TwnhsE  HouseStyle_1.5Fin  HouseStyle_1.5Unf  \
# 700             False              False              False
# 401             False              False              False
# 582             False              False              False
# 376             False              False              False
# 271             False              False              False
# ...               ...                ...                ...
# 849             False              False              False
# 1034            False              False              False
# 811              True              False              False
# 1442            False              False              False
# 716             False              False              False
#
#       HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  \
# 700                True              False              False
# 401                True              False              False
# 582               False              False              False
# 376               False              False              False
# 271                True              False              False
# ...                 ...                ...                ...
# 849               False              False              False
# 1034               True              False              False
# 811                True              False              False
# 1442              False              False              False
# 716               False              False              False
#
#       HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Flat  \
# 700               False              False            False           False
# 401               False              False            False           False
# 582               False               True            False           False
# 376               False               True            False           False
# 271               False              False            False            True
# ...                 ...                ...              ...             ...
# 849               False              False             True           False
# 1034              False              False            False           False
# 811               False              False            False           False
# 1442               True              False            False           False
# 716                True              False            False           False
#
#       RoofStyle_Gable  RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  \
# 700             False              False           True              False
# 401              True              False          False              False
# 582              True              False          False              False
# 376              True              False          False              False
# 271             False              False          False              False
# ...               ...                ...            ...                ...
# 849             False              False           True              False
# 1034             True              False          False              False
# 811              True              False          False              False
# 1442             True              False          False              False
# 716              True              False          False              False
#
#       RoofStyle_Shed  RoofMatl_ClyTile  RoofMatl_CompShg  RoofMatl_Membran  \
# 700            False             False              True             False
# 401            False             False              True             False
# 582            False             False              True             False
# 376            False             False              True             False
# 271            False             False             False              True
# ...              ...               ...               ...               ...
# 849            False             False              True             False
# 1034           False             False              True             False
# 811            False             False              True             False
# 1442           False             False              True             False
# 716            False             False              True             False
#
#       RoofMatl_Metal  RoofMatl_Roll  RoofMatl_Tar&Grv  RoofMatl_WdShake  \
# 700            False          False             False             False
# 401            False          False             False             False
# 582            False          False             False             False
# 376            False          False             False             False
# 271            False          False             False             False
# ...              ...            ...               ...               ...
# 849            False          False             False             False
# 1034           False          False             False             False
# 811            False          False             False             False
# 1442           False          False             False             False
# 716            False          False             False             False
#
#       RoofMatl_WdShngl  Exterior1st_AsbShng  Exterior1st_AsphShn  \
# 700              False                False                False
# 401              False                False                False
# 582              False                False                False
# 376              False                False                False
# 271              False                False                False
# ...                ...                  ...                  ...
# 849              False                False                False
# 1034             False                False                False
# 811              False                False                False
# 1442             False                False                False
# 716              False                False                False
#
#       Exterior1st_BrkComm  Exterior1st_BrkFace  Exterior1st_CBlock  \
# 700                 False                False               False
# 401                 False                False               False
# 582                 False                False               False
# 376                 False                False               False
# 271                 False                False               False
# ...                   ...                  ...                 ...
# 849                 False                False               False
# 1034                False                False               False
# 811                 False                False               False
# 1442                False                False               False
# 716                 False                False               False
#
#       Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 700                 False                False                False
# 401                 False                False                False
# 582                 False                 True                False
# 376                 False                False                False
# 271                 False                False                False
# ...                   ...                  ...                  ...
# 849                 False                False                False
# 1034                False                False                False
# 811                 False                False                False
# 1442                False                False                False
# 716                 False                False                False
#
#       Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 700                 False                False              False
# 401                 False                False              False
# 582                 False                False              False
# 376                 False                False              False
# 271                 False                 True              False
# ...                   ...                  ...                ...
# 849                 False                 True              False
# 1034                 True                False              False
# 811                 False                False              False
# 1442                False                False              False
# 716                 False                False              False
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 700                False                 True                False
# 401                False                 True                False
# 582                False                False                False
# 376                False                 True                False
# 271                False                False                False
# ...                  ...                  ...                  ...
# 849                False                False                False
# 1034               False                False                False
# 811                False                 True                False
# 1442               False                 True                False
# 716                False                False                 True
#
#       Exterior1st_WdShing  Exterior2nd_AsbShng  Exterior2nd_AsphShn  \
# 700                 False                False                False
# 401                 False                False                False
# 582                 False                False                False
# 376                 False                False                False
# 271                 False                False                False
# ...                   ...                  ...                  ...
# 849                 False                False                False
# 1034                False                False                False
# 811                 False                False                False
# 1442                False                False                False
# 716                 False                False                False
#
#       Exterior2nd_Brk Cmn  Exterior2nd_BrkFace  Exterior2nd_CBlock  \
# 700                 False                False               False
# 401                 False                False               False
# 582                 False                False               False
# 376                 False                False               False
# 271                 False                False               False
# ...                   ...                  ...                 ...
# 849                 False                False               False
# 1034                False                False               False
# 811                 False                False               False
# 1442                False                False               False
# 716                 False                False               False
#
#       Exterior2nd_CmentBd  Exterior2nd_HdBoard  Exterior2nd_ImStucc  \
# 700                 False                False                False
# 401                 False                False                False
# 582                 False                 True                False
# 376                 False                False                False
# 271                 False                False                False
# ...                   ...                  ...                  ...
# 849                 False                False                False
# 1034                False                False                False
# 811                 False                False                False
# 1442                False                False                False
# 716                 False                False                False
#
#       Exterior2nd_MetalSd  Exterior2nd_Other  Exterior2nd_Plywood  \
# 700                 False              False                False
# 401                 False              False                False
# 582                 False              False                False
# 376                 False              False                False
# 271                 False              False                 True
# ...                   ...                ...                  ...
# 849                 False              False                 True
# 1034                 True              False                False
# 811                 False              False                False
# 1442                False              False                False
# 716                 False              False                False
#
#       Exterior2nd_Stone  Exterior2nd_Stucco  Exterior2nd_VinylSd  \
# 700               False               False                 True
# 401               False               False                 True
# 582               False               False                False
# 376               False               False                 True
# 271               False               False                False
# ...                 ...                 ...                  ...
# 849               False               False                False
# 1034              False               False                False
# 811               False               False                 True
# 1442              False               False                 True
# 716               False               False                 True
#
#       Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  ExterQual_Ex  ExterQual_Fa  \
# 700                 False                False         False         False
# 401                 False                False         False         False
# 582                 False                False         False         False
# 376                 False                False         False         False
# 271                 False                False         False         False
# ...                   ...                  ...           ...           ...
# 849                 False                False         False         False
# 1034                False                False         False         False
# 811                 False                False         False         False
# 1442                False                False          True         False
# 716                 False                False         False         False
#
#       ExterQual_Gd  ExterQual_TA  ExterCond_Ex  ExterCond_Fa  ExterCond_Gd  \
# 700           True         False         False         False         False
# 401           True         False         False         False         False
# 582          False          True         False         False          True
# 376           True         False         False         False         False
# 271          False          True         False         False         False
# ...            ...           ...           ...           ...           ...
# 849           True         False         False         False          True
# 1034         False          True         False         False          True
# 811           True         False         False         False         False
# 1442         False         False         False         False         False
# 716          False          True         False         False          True
#
#       ExterCond_Po  ExterCond_TA  Foundation_BrkTil  Foundation_CBlock  \
# 700          False          True              False              False
# 401          False          True              False              False
# 582          False         False              False               True
# 376          False          True              False              False
# 271          False          True              False               True
# ...            ...           ...                ...                ...
# 849          False         False              False               True
# 1034         False         False              False              False
# 811          False          True              False              False
# 1442         False          True              False              False
# 716          False         False               True              False
#
#       Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# 700               True            False             False            False
# 401               True            False             False            False
# 582              False            False             False            False
# 376               True            False             False            False
# 271              False            False             False            False
# ...                ...              ...               ...              ...
# 849              False            False             False            False
# 1034              True            False             False            False
# 811               True            False             False            False
# 1442              True            False             False            False
# 716              False            False             False            False
#
#       BsmtQual_Ex  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_TA  BsmtCond_Fa  \
# 700          True        False        False        False        False
# 401         False        False         True        False        False
# 582         False        False         True        False        False
# 376         False        False         True        False        False
# 271         False        False         True        False        False
# ...           ...          ...          ...          ...          ...
# 849         False        False        False         True        False
# 1034        False         True        False        False         True
# 811         False        False         True        False        False
# 1442         True        False        False        False        False
# 716         False        False        False         True        False
#
#       BsmtCond_Gd  BsmtCond_Po  BsmtCond_TA  BsmtExposure_Av  BsmtExposure_Gd  \
# 700         False        False         True            False             True
# 401         False        False         True             True            False
# 582         False        False         True             True            False
# 376         False        False         True             True            False
# 271         False        False         True            False             True
# ...           ...          ...          ...              ...              ...
# 849         False        False         True            False            False
# 1034        False        False        False            False            False
# 811         False        False         True            False             True
# 1442        False        False         True             True            False
# 716         False        False         True            False            False
#
#       BsmtExposure_Mn  BsmtExposure_No  BsmtFinType1_ALQ  BsmtFinType1_BLQ  \
# 700             False            False             False             False
# 401             False            False             False             False
# 582             False            False             False             False
# 376             False            False             False             False
# 271             False            False             False             False
# ...               ...              ...               ...               ...
# 849             False             True             False             False
# 1034            False             True             False             False
# 811             False            False             False             False
# 1442            False            False             False             False
# 716             False             True             False             False
#
#       BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_Rec  BsmtFinType1_Unf  \
# 700               True             False             False             False
# 401               True             False             False             False
# 582               True             False             False             False
# 376               True             False             False             False
# 271              False              True             False             False
# ...                ...               ...               ...               ...
# 849              False             False             False              True
# 1034             False             False             False              True
# 811               True             False             False             False
# 1442              True             False             False             False
# 716              False             False             False              True
#
#       BsmtFinType2_ALQ  BsmtFinType2_BLQ  BsmtFinType2_GLQ  BsmtFinType2_LwQ  \
# 700              False             False             False             False
# 401              False             False             False             False
# 582              False             False             False             False
# 376              False             False             False             False
# 271              False             False              True             False
# ...                ...               ...               ...               ...
# 849              False             False             False             False
# 1034             False             False             False             False
# 811              False             False             False             False
# 1442             False             False             False             False
# 716              False             False             False             False
#
#       BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_Floor  Heating_GasA  \
# 700              False              True          False          True
# 401              False              True          False          True
# 582              False              True          False          True
# 376              False              True          False          True
# 271              False             False          False          True
# ...                ...               ...            ...           ...
# 849              False              True          False          True
# 1034             False              True          False          True
# 811              False              True          False          True
# 1442             False              True          False          True
# 716              False              True          False          True
#
#       Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  HeatingQC_Ex  \
# 700          False         False         False         False          True
# 401          False         False         False         False          True
# 582          False         False         False         False         False
# 376          False         False         False         False          True
# 271          False         False         False         False          True
# ...            ...           ...           ...           ...           ...
# 849          False         False         False         False          True
# 1034         False         False         False         False          True
# 811          False         False         False         False          True
# 1442         False         False         False         False          True
# 716          False         False         False         False          True
#
#       HeatingQC_Fa  HeatingQC_Gd  HeatingQC_Po  HeatingQC_TA  CentralAir_N  \
# 700          False         False         False         False         False
# 401          False         False         False         False         False
# 582          False         False         False          True         False
# 376          False         False         False         False         False
# 271          False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 849          False         False         False         False         False
# 1034         False         False         False         False         False
# 811          False         False         False         False         False
# 1442         False         False         False         False         False
# 716          False         False         False         False         False
#
#       CentralAir_Y  Electrical_FuseA  Electrical_FuseF  Electrical_FuseP  \
# 700           True             False             False             False
# 401           True             False             False             False
# 582           True             False             False             False
# 376           True             False             False             False
# 271           True             False             False             False
# ...            ...               ...               ...               ...
# 849           True             False             False             False
# 1034          True             False             False             False
# 811           True             False             False             False
# 1442          True             False             False             False
# 716           True             False             False             False
#
#       Electrical_Mix  Electrical_SBrkr  KitchenQual_Ex  KitchenQual_Fa  \
# 700            False              True           False           False
# 401            False              True           False           False
# 582            False              True           False           False
# 376            False              True           False           False
# 271            False              True           False           False
# ...              ...               ...             ...             ...
# 849            False              True           False           False
# 1034           False              True           False            True
# 811            False              True           False           False
# 1442           False              True            True           False
# 716            False              True           False           False
#
#       KitchenQual_Gd  KitchenQual_TA  Functional_Maj1  Functional_Maj2  \
# 700             True           False            False            False
# 401             True           False            False            False
# 582            False            True            False            False
# 376            False            True            False            False
# 271            False            True            False            False
# ...              ...             ...              ...              ...
# 849            False            True            False            False
# 1034           False           False            False            False
# 811             True           False            False            False
# 1442           False           False            False            False
# 716            False            True            False            False
#
#       Functional_Min1  Functional_Min2  Functional_Mod  Functional_Sev  \
# 700             False            False           False           False
# 401             False            False           False           False
# 582             False            False           False           False
# 376             False            False           False           False
# 271             False            False            True           False
# ...               ...              ...             ...             ...
# 849             False            False           False           False
# 1034            False            False           False           False
# 811             False            False           False           False
# 1442            False            False           False           False
# 716             False            False           False           False
#
#       Functional_Typ  GarageType_2Types  GarageType_Attchd  \
# 700             True              False               True
# 401             True              False               True
# 582             True              False              False
# 376             True              False              False
# 271            False              False               True
# ...              ...                ...                ...
# 849             True              False               True
# 1034            True              False              False
# 811             True              False               True
# 1442            True              False               True
# 716             True              False              False
#
#       GarageType_Basment  GarageType_BuiltIn  GarageType_CarPort  \
# 700                False               False               False
# 401                False               False               False
# 582                False               False               False
# 376                False               False               False
# 271                False               False               False
# ...                  ...                 ...                 ...
# 849                False               False               False
# 1034                True               False               False
# 811                False               False               False
# 1442               False               False               False
# 716                False               False               False
#
#       GarageType_Detchd  GarageFinish_Fin  GarageFinish_RFn  GarageFinish_Unf  \
# 700               False              True             False             False
# 401               False              True             False             False
# 582               False             False             False             False
# 376                True             False             False              True
# 271               False             False             False              True
# ...                 ...               ...               ...               ...
# 849               False             False              True             False
# 1034              False             False             False              True
# 811               False              True             False             False
# 1442              False              True             False             False
# 716                True             False             False              True
#
#       GarageQual_Ex  GarageQual_Fa  GarageQual_Gd  GarageQual_Po  \
# 700           False          False          False          False
# 401           False          False          False          False
# 582           False          False          False          False
# 376           False          False          False          False
# 271           False          False          False          False
# ...             ...            ...            ...            ...
# 849           False          False          False          False
# 1034          False           True          False          False
# 811           False          False          False          False
# 1442          False          False          False          False
# 716           False          False          False          False
#
#       GarageQual_TA  GarageCond_Ex  GarageCond_Fa  GarageCond_Gd  \
# 700            True          False          False          False
# 401            True          False          False          False
# 582           False          False          False          False
# 376            True          False          False          False
# 271            True          False          False          False
# ...             ...            ...            ...            ...
# 849            True          False          False          False
# 1034          False          False          False          False
# 811            True          False          False          False
# 1442           True          False          False          False
# 716            True          False          False          False
#
#       GarageCond_Po  GarageCond_TA  PavedDrive_N  PavedDrive_P  PavedDrive_Y  \
# 700           False           True         False         False          True
# 401           False           True         False         False          True
# 582           False          False         False         False          True
# 376           False           True         False         False          True
# 271           False           True         False         False          True
# ...             ...            ...           ...           ...           ...
# 849           False           True         False         False          True
# 1034          False           True         False         False          True
# 811           False           True         False         False          True
# 1442          False           True         False         False          True
# 716           False           True         False          True         False
#
#       SaleType_COD  SaleType_CWD  SaleType_Con  SaleType_ConLD  \
# 700          False         False         False           False
# 401          False         False         False           False
# 582          False         False         False           False
# 376          False         False         False           False
# 271          False         False         False           False
# ...            ...           ...           ...             ...
# 849          False         False         False           False
# 1034         False         False         False           False
# 811          False         False         False            True
# 1442         False         False         False           False
# 716          False         False         False           False
#
#       SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 700            False           False         False         False         True
# 401            False           False          True         False        False
# 582            False           False         False         False         True
# 376            False           False         False         False         True
# 271            False           False         False         False         True
# ...              ...             ...           ...           ...          ...
# 849            False           False         False         False         True
# 1034           False           False         False         False         True
# 811            False           False         False         False        False
# 1442           False           False         False         False         True
# 716            False           False         False         False         True
#
#       SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 700                   False                  False                 False
# 401                   False                  False                 False
# 582                   False                  False                 False
# 376                   False                  False                 False
# 271                   False                  False                 False
# ...                     ...                    ...                   ...
# 849                   False                  False                 False
# 1034                  False                  False                 False
# 811                   False                  False                 False
# 1442                  False                  False                 False
# 716                   False                  False                 False
#
#       SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# 700                  False                  True                  False
# 401                  False                 False                   True
# 582                  False                  True                  False
# 376                  False                  True                  False
# 271                  False                  True                  False
# ...                    ...                   ...                    ...
# 849                  False                  True                  False
# 1034                 False                  True                  False
# 811                  False                  True                  False
# 1442                 False                  True                  False
# 716                  False                  True                  False
#
# [1168 rows x 266 columns]

# %% [markdown]
# **Lasso가 왜 이렇게 나왔을까?**

# %%
def get_top_bottom_coef(model):
    # coef_ 속성을 기반으로 Series 객체를 생성. index는 컬럼명. 
    coef = pd.Series(model.coef_, index=X_features.columns)
    
    # + 상위 10개 , - 하위 10개 coefficient 추출하여 반환.
    coef_high = coef.sort_values(ascending=False).head(10)
    coef_low = coef.sort_values(ascending=False).tail(10)
    return coef_high, coef_low

# %%
def visualize_coefficient(models):
    # 3개 회귀 모델의 시각화를 위해 3개의 컬럼을 가지는 subplot 생성
    fig, axs = plt.subplots(figsize=(24,10),nrows=1, ncols=3)
    fig.tight_layout() 
    # 입력인자로 받은 list객체인 models에서 차례로 model을 추출하여 회귀 계수 시각화. 
    for i_num, model in enumerate(models):
        # 상위 10개, 하위 10개 회귀 계수를 구하고, 이를 판다스 concat으로 결합. 
        coef_high, coef_low = get_top_bottom_coef(model)
        coef_concat = pd.concat( [coef_high , coef_low] )
        # 순차적으로 ax subplot에 barchar로 표현. 한 화면에 표현하기 위해 tick label 위치와 font 크기 조정. 
        axs[i_num].set_title(model.__class__.__name__+' Coeffiecents', size=25)
        axs[i_num].tick_params(axis="y",direction="in", pad=-120)
        for label in (axs[i_num].get_xticklabels() + axs[i_num].get_yticklabels()):
            label.set_fontsize(22)
        sns.barplot(x=coef_concat.values, y=coef_concat.index , ax=axs[i_num])

# 앞 예제에서 학습한 lr_reg, ridge_reg, lasso_reg 모델의 회귀 계수 시각화.    
models = [lr_reg, ridge_reg, lasso_reg]
visualize_coefficient(models)

# %% [markdown]
# ### **5 fold Cross Validation : 모델별 RMSE, 평균 RMSE**

# %%
from sklearn.model_selection import cross_val_score

def get_avg_rmse_cv(models):
    for model in models:
        # 분할하지 않고 전체 데이터로 cross_val_score( ) 수행. 모델별 CV RMSE값과 평균 RMSE 출력
        rmse_list = np.sqrt(-cross_val_score(model, X_features, y_target,
                                             scoring="neg_mean_squared_error", cv = 5))
        rmse_avg = np.mean(rmse_list)
        print('\n{0} CV RMSE 값 리스트: {1}'.format( model.__class__.__name__, np.round(rmse_list, 3)))
        print('{0} CV 평균 RMSE 값: {1}'.format( model.__class__.__name__, np.round(rmse_avg, 3)))

# 앞 예제에서 학습한 lr_reg, ridge_reg, lasso_reg 모델의 CV RMSE값 출력           
models = [lr_reg, ridge_reg, lasso_reg]
get_avg_rmse_cv(models)
# Out:
# LinearRegression CV RMSE 값 리스트: [0.135 0.164 0.166 0.111 0.198]
# LinearRegression CV 평균 RMSE 값: 0.155
#
# Ridge CV RMSE 값 리스트: [0.117 0.154 0.142 0.116 0.189]
# Ridge CV 평균 RMSE 값: 0.144
#
# Lasso CV RMSE 값 리스트: [0.161 0.204 0.177 0.181 0.265]
# Lasso CV 평균 RMSE 값: 0.198

# %% [markdown]
# ### **하이퍼 파라미터 튜닝 (Alpha)**

# %%
from sklearn.model_selection import GridSearchCV

def print_best_params(model, params):
    grid_model = GridSearchCV(model, param_grid=params, 
                              scoring='neg_mean_squared_error', cv=5)
    # 분류와는 다르게 회귀에서 쓰는 평가 지표가 작아야 좋기때문에, neg를 쓰는거고 다시 - 붙여줘야함
    grid_model.fit(X_features, y_target)
    rmse = np.sqrt(-1* grid_model.best_score_)
    print('{0} 5 CV 시 최적 평균 RMSE 값: {1}, 최적 alpha:{2}'.format(model.__class__.__name__,
                                        np.round(rmse, 4), grid_model.best_params_))
    return grid_model.best_estimator_

ridge_params = { 'alpha':[0.05, 0.1, 1, 5, 8, 10, 12, 15, 20] }
lasso_params = { 'alpha':[0.001, 0.005, 0.008, 0.05, 0.03, 0.1, 0.5, 1,5, 10] }
best_rige = print_best_params(ridge_reg, ridge_params)
best_lasso = print_best_params(lasso_reg, lasso_params)
# Out:
# Ridge 5 CV 시 최적 평균 RMSE 값: 0.1417, 최적 alpha:{'alpha': 10}
# Lasso 5 CV 시 최적 평균 RMSE 값: 0.142, 최적 alpha:{'alpha': 0.001}

# %%
# 앞의 최적화 alpha값으로 학습데이터로 학습, 테스트 데이터로 예측 및 평가 수행. 
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
ridge_reg = Ridge(alpha=10)
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)

# 모든 모델의 RMSE 출력
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)

# 모든 모델의 회귀 계수 시각화 
models = [lr_reg, ridge_reg, lasso_reg]
visualize_coefficient(models)
# Out:
# LinearRegression 로그 변환된 RMSE: 0.132
# Ridge 로그 변환된 RMSE: 0.124
# Lasso 로그 변환된 RMSE: 0.12

# %% [markdown]
#  ### **데이터 왜곡 로그 변환 후 성능 평가**
#
#  앞에서 로그변환은 target 대상이었음

# %% [markdown]
# 음수 값이 있는 데이터는 로그에 넣을 수 없으므로 양수가 되도록 처리한 이후에 학습, 태스트 데이터 모두 일괄적으로 변환한다.

# %%
house_df.dtypes[house_df.dtypes != 'object'].index
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
from scipy.stats import skew

# object가 아닌 숫자형 피처의 칼럼 index 객체 추출.
features_index = house_df.dtypes[house_df.dtypes != 'object'].index
# house_df에 칼럼 index를 [ ]로 입력하면 해당하는 칼럼 데이터 세트 반환. apply lambda로 skew( ) 호출
skew_features = house_df[features_index].apply(lambda x : skew(x))
# skew(왜곡) 정도가 1 이상인 칼럼만 추출.
skew_features_top = skew_features[skew_features > 1]
print(skew_features_top.sort_values(ascending=False))
# Out:
# MiscVal          24.451640
# PoolArea         14.813135
# LotArea          12.195142
# 3SsnPorch        10.293752
# LowQualFinSF      9.002080
# KitchenAbvGr      4.483784
# BsmtFinSF2        4.250888
# ScreenPorch       4.117977
# BsmtHalfBath      4.099186
# EnclosedPorch     3.086696
# MasVnrArea        2.673661
# LotFrontage       2.382499
# OpenPorchSF       2.361912
# BsmtFinSF1        1.683771
# WoodDeckSF        1.539792
# TotalBsmtSF       1.522688
# MSSubClass        1.406210
# 1stFlrSF          1.375342
# GrLivArea         1.365156
# dtype: float64

# %% [markdown]
# 왜곡도 출력

# %%
house_df_ohe.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710             1             0
# 1      1262         0             0       1262             0             1
# 2       920       866             0       1786             1             0
# 3       961       756             0       1717             1             0
# 4      1145      1053             0       2198             1             0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         2         1             3             1             8           0
# 1         2         0             3             1             6           1
# 2         2         1             3             1             6           1
# 3         1         0             3             1             7           1
# 4         2         1             4             1             9           1
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0       2003.0           2         548           0           61
# 1       1976.0           2         460         298            0
# 2       2001.0           2         608           0           42
# 3       1998.0           3         642           0           35
# 4       2000.0           3         836         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice  MSZoning_C (all)  MSZoning_FV  MSZoning_RH  MSZoning_RL  \
# 0  12.247699             False        False        False         True
# 1  12.109016             False        False        False         True
# 2  12.317171             False        False        False         True
# 3  11.849405             False        False        False         True
# 4  12.429220             False        False        False         True
#
#    MSZoning_RM  Street_Grvl  Street_Pave  LotShape_IR1  LotShape_IR2  \
# 0        False        False         True         False         False
# 1        False        False         True         False         False
# 2        False        False         True          True         False
# 3        False        False         True          True         False
# 4        False        False         True          True         False
#
#    LotShape_IR3  LotShape_Reg  LandContour_Bnk  LandContour_HLS  \
# 0         False          True            False            False
# 1         False          True            False            False
# 2         False         False            False            False
# 3         False         False            False            False
# 4         False         False            False            False
#
#    LandContour_Low  LandContour_Lvl  Utilities_AllPub  Utilities_NoSeWa  \
# 0            False             True              True             False
# 1            False             True              True             False
# 2            False             True              True             False
# 3            False             True              True             False
# 4            False             True              True             False
#
#    LotConfig_Corner  LotConfig_CulDSac  LotConfig_FR2  LotConfig_FR3  \
# 0             False              False          False          False
# 1             False              False           True          False
# 2             False              False          False          False
# 3              True              False          False          False
# 4             False              False           True          False
#
#    LotConfig_Inside  LandSlope_Gtl  LandSlope_Mod  LandSlope_Sev  \
# 0              True           True          False          False
# 1             False           True          False          False
# 2              True           True          False          False
# 3             False           True          False          False
# 4             False           True          False          False
#
#    Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 0                 False                 False                  True
# 1                 False                 False                 False
# 2                 False                 False                  True
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                  True                 False                 False
# 4                 False                 False                 False
#
#    Neighborhood_IDOTRR  Neighborhood_MeadowV  Neighborhood_Mitchel  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_NAmes  Neighborhood_NPkVill  Neighborhood_NWAmes  \
# 0               False                 False                False
# 1               False                 False                False
# 2               False                 False                False
# 3               False                 False                False
# 4               False                 False                False
#
#    Neighborhood_NoRidge  Neighborhood_NridgHt  Neighborhood_OldTown  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                  True                 False                 False
#
#    Neighborhood_SWISU  Neighborhood_Sawyer  Neighborhood_SawyerW  \
# 0               False                False                 False
# 1               False                False                 False
# 2               False                False                 False
# 3               False                False                 False
# 4               False                False                 False
#
#    Neighborhood_Somerst  Neighborhood_StoneBr  Neighborhood_Timber  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    Neighborhood_Veenker  Condition1_Artery  Condition1_Feedr  Condition1_Norm  \
# 0                 False              False             False             True
# 1                  True              False              True            False
# 2                 False              False             False             True
# 3                 False              False             False             True
# 4                 False              False             False             True
#
#    Condition1_PosA  Condition1_PosN  Condition1_RRAe  Condition1_RRAn  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Condition1_RRNe  Condition1_RRNn  Condition2_Artery  Condition2_Feedr  \
# 0            False            False              False             False
# 1            False            False              False             False
# 2            False            False              False             False
# 3            False            False              False             False
# 4            False            False              False             False
#
#    Condition2_Norm  Condition2_PosA  Condition2_PosN  Condition2_RRAe  \
# 0             True            False            False            False
# 1             True            False            False            False
# 2             True            False            False            False
# 3             True            False            False            False
# 4             True            False            False            False
#
#    Condition2_RRAn  Condition2_RRNn  BldgType_1Fam  BldgType_2fmCon  \
# 0            False            False           True            False
# 1            False            False           True            False
# 2            False            False           True            False
# 3            False            False           True            False
# 4            False            False           True            False
#
#    BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  HouseStyle_1.5Fin  \
# 0            False           False            False              False
# 1            False           False            False              False
# 2            False           False            False              False
# 3            False           False            False              False
# 4            False           False            False              False
#
#    HouseStyle_1.5Unf  HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  \
# 0              False              False              False              False
# 1              False               True              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Flat  \
# 0               True              False            False           False
# 1              False              False            False           False
# 2               True              False            False           False
# 3               True              False            False           False
# 4               True              False            False           False
#
#    RoofStyle_Gable  RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  \
# 0             True              False          False              False
# 1             True              False          False              False
# 2             True              False          False              False
# 3             True              False          False              False
# 4             True              False          False              False
#
#    RoofStyle_Shed  RoofMatl_ClyTile  RoofMatl_CompShg  RoofMatl_Membran  \
# 0           False             False              True             False
# 1           False             False              True             False
# 2           False             False              True             False
# 3           False             False              True             False
# 4           False             False              True             False
#
#    RoofMatl_Metal  RoofMatl_Roll  RoofMatl_Tar&Grv  RoofMatl_WdShake  \
# 0           False          False             False             False
# 1           False          False             False             False
# 2           False          False             False             False
# 3           False          False             False             False
# 4           False          False             False             False
#
#    RoofMatl_WdShngl  Exterior1st_AsbShng  Exterior1st_AsphShn  \
# 0             False                False                False
# 1             False                False                False
# 2             False                False                False
# 3             False                False                False
# 4             False                False                False
#
#    Exterior1st_BrkComm  Exterior1st_BrkFace  Exterior1st_CBlock  \
# 0                False                False               False
# 1                False                False               False
# 2                False                False               False
# 3                False                False               False
# 4                False                False               False
#
#    Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 0                False                False              False
# 1                 True                False              False
# 2                False                False              False
# 3                False                False              False
# 4                False                False              False
#
#    Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 0               False                 True                False
# 1               False                False                False
# 2               False                 True                False
# 3               False                False                 True
# 4               False                 True                False
#
#    Exterior1st_WdShing  Exterior2nd_AsbShng  Exterior2nd_AsphShn  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_Brk Cmn  Exterior2nd_BrkFace  Exterior2nd_CBlock  \
# 0                False                False               False
# 1                False                False               False
# 2                False                False               False
# 3                False                False               False
# 4                False                False               False
#
#    Exterior2nd_CmentBd  Exterior2nd_HdBoard  Exterior2nd_ImStucc  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_MetalSd  Exterior2nd_Other  Exterior2nd_Plywood  \
# 0                False              False                False
# 1                 True              False                False
# 2                False              False                False
# 3                False              False                False
# 4                False              False                False
#
#    Exterior2nd_Stone  Exterior2nd_Stucco  Exterior2nd_VinylSd  \
# 0              False               False                 True
# 1              False               False                False
# 2              False               False                 True
# 3              False               False                False
# 4              False               False                 True
#
#    Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  ExterQual_Ex  ExterQual_Fa  \
# 0                False                False         False         False
# 1                False                False         False         False
# 2                False                False         False         False
# 3                False                 True         False         False
# 4                False                False         False         False
#
#    ExterQual_Gd  ExterQual_TA  ExterCond_Ex  ExterCond_Fa  ExterCond_Gd  \
# 0          True         False         False         False         False
# 1         False          True         False         False         False
# 2          True         False         False         False         False
# 3         False          True         False         False         False
# 4          True         False         False         False         False
#
#    ExterCond_Po  ExterCond_TA  Foundation_BrkTil  Foundation_CBlock  \
# 0         False          True              False              False
# 1         False          True              False               True
# 2         False          True              False              False
# 3         False          True               True              False
# 4         False          True              False              False
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# 0              True            False             False            False
# 1             False            False             False            False
# 2              True            False             False            False
# 3             False            False             False            False
# 4              True            False             False            False
#
#    BsmtQual_Ex  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_TA  BsmtCond_Fa  \
# 0        False        False         True        False        False
# 1        False        False         True        False        False
# 2        False        False         True        False        False
# 3        False        False        False         True        False
# 4        False        False         True        False        False
#
#    BsmtCond_Gd  BsmtCond_Po  BsmtCond_TA  BsmtExposure_Av  BsmtExposure_Gd  \
# 0        False        False         True            False            False
# 1        False        False         True            False             True
# 2        False        False         True            False            False
# 3         True        False        False            False            False
# 4        False        False         True             True            False
#
#    BsmtExposure_Mn  BsmtExposure_No  BsmtFinType1_ALQ  BsmtFinType1_BLQ  \
# 0            False             True             False             False
# 1            False            False              True             False
# 2             True            False             False             False
# 3            False             True              True             False
# 4            False            False             False             False
#
#    BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_Rec  BsmtFinType1_Unf  \
# 0              True             False             False             False
# 1             False             False             False             False
# 2              True             False             False             False
# 3             False             False             False             False
# 4              True             False             False             False
#
#    BsmtFinType2_ALQ  BsmtFinType2_BLQ  BsmtFinType2_GLQ  BsmtFinType2_LwQ  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_Floor  Heating_GasA  \
# 0             False              True          False          True
# 1             False              True          False          True
# 2             False              True          False          True
# 3             False              True          False          True
# 4             False              True          False          True
#
#    Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  HeatingQC_Ex  \
# 0         False         False         False         False          True
# 1         False         False         False         False          True
# 2         False         False         False         False          True
# 3         False         False         False         False         False
# 4         False         False         False         False          True
#
#    HeatingQC_Fa  HeatingQC_Gd  HeatingQC_Po  HeatingQC_TA  CentralAir_N  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False          True         False         False         False
# 4         False         False         False         False         False
#
#    CentralAir_Y  Electrical_FuseA  Electrical_FuseF  Electrical_FuseP  \
# 0          True             False             False             False
# 1          True             False             False             False
# 2          True             False             False             False
# 3          True             False             False             False
# 4          True             False             False             False
#
#    Electrical_Mix  Electrical_SBrkr  KitchenQual_Ex  KitchenQual_Fa  \
# 0           False              True           False           False
# 1           False              True           False           False
# 2           False              True           False           False
# 3           False              True           False           False
# 4           False              True           False           False
#
#    KitchenQual_Gd  KitchenQual_TA  Functional_Maj1  Functional_Maj2  \
# 0            True           False            False            False
# 1           False            True            False            False
# 2            True           False            False            False
# 3            True           False            False            False
# 4            True           False            False            False
#
#    Functional_Min1  Functional_Min2  Functional_Mod  Functional_Sev  \
# 0            False            False           False           False
# 1            False            False           False           False
# 2            False            False           False           False
# 3            False            False           False           False
# 4            False            False           False           False
#
#    Functional_Typ  GarageType_2Types  GarageType_Attchd  GarageType_Basment  \
# 0            True              False               True               False
# 1            True              False               True               False
# 2            True              False               True               False
# 3            True              False              False               False
# 4            True              False               True               False
#
#    GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
# 3               False               False               True
# 4               False               False              False
#
#    GarageFinish_Fin  GarageFinish_RFn  GarageFinish_Unf  GarageQual_Ex  \
# 0             False              True             False          False
# 1             False              True             False          False
# 2             False              True             False          False
# 3             False             False              True          False
# 4             False              True             False          False
#
#    GarageQual_Fa  GarageQual_Gd  GarageQual_Po  GarageQual_TA  GarageCond_Ex  \
# 0          False          False          False           True          False
# 1          False          False          False           True          False
# 2          False          False          False           True          False
# 3          False          False          False           True          False
# 4          False          False          False           True          False
#
#    GarageCond_Fa  GarageCond_Gd  GarageCond_Po  GarageCond_TA  PavedDrive_N  \
# 0          False          False          False           True         False
# 1          False          False          False           True         False
# 2          False          False          False           True         False
# 3          False          False          False           True         False
# 4          False          False          False           True         False
#
#    PavedDrive_P  PavedDrive_Y  SaleType_COD  SaleType_CWD  SaleType_Con  \
# 0         False          True         False         False         False
# 1         False          True         False         False         False
# 2         False          True         False         False         False
# 3         False          True         False         False         False
# 4         False          True         False         False         False
#
#    SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# 0           False           False           False         False         False
# 1           False           False           False         False         False
# 2           False           False           False         False         False
# 3           False           False           False         False         False
# 4           False           False           False         False         False
#
#    SaleType_WD  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# 0         True                  False                  False
# 1         True                  False                  False
# 2         True                  False                  False
# 3         True                   True                  False
# 4         True                  False                  False
#
#    SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 0                 False                 False                  True
# 1                 False                 False                  True
# 2                 False                 False                  True
# 3                 False                 False                 False
# 4                 False                 False                  True
#
#    SaleCondition_Partial
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %% [markdown]
# ### **왜곡도가 1인 피처들은 로그변환 적용하고 하이퍼파라미터 튜닝**

# %%
house_df[skew_features_top.index] = np.log1p(house_df[skew_features_top.index])

# %%
# Skew가 높은 피처들을 로그 변환 했으므로 다시 원-핫 인코딩 적용 및 피처/타겟 데이터 셋 생성,
house_df_ohe = pd.get_dummies(house_df)
y_target = house_df_ohe['SalePrice']
X_features = house_df_ohe.drop('SalePrice',axis=1, inplace=False)
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.2, random_state=156)

# 피처들을 로그 변환 후 다시 최적 하이퍼 파라미터와 RMSE 출력
ridge_params = { 'alpha':[0.05, 0.1, 1, 5, 8, 10, 12, 15, 20] }
lasso_params = { 'alpha':[0.001, 0.005, 0.008, 0.05, 0.03, 0.1, 0.5, 1,5, 10] }
best_ridge = print_best_params(ridge_reg, ridge_params)
best_lasso = print_best_params(lasso_reg, lasso_params)
# Out:
# Ridge 5 CV 시 최적 평균 RMSE 값: 0.1275, 최적 alpha:{'alpha': 10}
# Lasso 5 CV 시 최적 평균 RMSE 값: 0.1252, 최적 alpha:{'alpha': 0.001}

# %%
# 앞의 최적화 alpha값으로 학습데이터로 학습, 테스트 데이터로 예측 및 평가 수행. 
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
ridge_reg = Ridge(alpha=10)
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)

# 모든 모델의 RMSE 출력
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)

# 모든 모델의 회귀 계수 시각화 
models = [lr_reg, ridge_reg, lasso_reg]
visualize_coefficient(models)
# Out:
# LinearRegression 로그 변환된 RMSE: 0.128
# Ridge 로그 변환된 RMSE: 0.122
# Lasso 로그 변환된 RMSE: 0.119

# %% [markdown]
# #### **이상치 데이터 검출을 위해 주요 피쳐인 GrLivArea값(집의 크기)에 대한 산점도 확인**

# %%
plt.scatter(x = house_df_org['GrLivArea'], y = house_df_org['SalePrice'])
plt.ylabel('SalePrice', fontsize=15)
plt.xlabel('GrLivArea', fontsize=15)
plt.show()

# %% [markdown]
# 집이 큰데 가격이 낮은 2개데이터가 있음 이를 아웃라이어로 규정한다.

# %%
# GrLivArea와 SalePrice 모두 로그 변환되었으므로 이를 반영한 조건 생성. 
cond1 = house_df_ohe['GrLivArea'] > np.log1p(4000)
cond2 = house_df_ohe['SalePrice'] < np.log1p(500000)
# 넓이가 4000보다 큰데, 가격이 500000보다 낮은 데이터 추출

outlier_index = house_df_ohe[cond1 & cond2].index

print('아웃라이어 레코드 index :', outlier_index.values)
print('아웃라이어 삭제 전 house_df_ohe shape:', house_df_ohe.shape)
# DataFrame의 index를 이용하여 아웃라이어 레코드 삭제. 
house_df_ohe.drop(outlier_index , axis=0, inplace=True)
print('아웃라이어 삭제 후 house_df_ohe shape:', house_df_ohe.shape)
# Out:
# 아웃라이어 레코드 index : [ 523 1298]
# 아웃라이어 삭제 전 house_df_ohe shape: (1460, 267)
# 아웃라이어 삭제 후 house_df_ohe shape: (1458, 267)

# %%
y_target = house_df_ohe['SalePrice']
X_features = house_df_ohe.drop('SalePrice',axis=1, inplace=False)
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.2, random_state=156)

ridge_params = { 'alpha':[0.05, 0.1, 1, 5, 8, 10, 12, 15, 20] }
lasso_params = { 'alpha':[0.001, 0.005, 0.008, 0.05, 0.03, 0.1, 0.5, 1,5, 10] }
best_ridge = print_best_params(ridge_reg, ridge_params)
best_lasso = print_best_params(lasso_reg, lasso_params)
# Out:
# Ridge 5 CV 시 최적 평균 RMSE 값: 0.1126, 최적 alpha:{'alpha': 8}
# Lasso 5 CV 시 최적 평균 RMSE 값: 0.1122, 최적 alpha:{'alpha': 0.001}

# %% [markdown]
# 0.01 정도 성능이 향상

# %%
# 앞의 최적화 alpha값으로 학습데이터로 학습, 테스트 데이터로 예측 및 평가 수행. 
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
ridge_reg = Ridge(alpha=8)
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)

# 모든 모델의 RMSE 출력
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)

# 모든 모델의 회귀 계수 시각화 
models = [lr_reg, ridge_reg, lasso_reg]
visualize_coefficient(models)
# Out:
# LinearRegression 로그 변환된 RMSE: 0.129
# Ridge 로그 변환된 RMSE: 0.103
# Lasso 로그 변환된 RMSE: 0.1

# %% [markdown]
# ### **Regression Tree Train/Predict/Evaluation**

# %% [markdown]
# ##### **XGBOOST, LIGHTGBM**

# %%
from xgboost import XGBRegressor

xgb_params = {'n_estimators':[1000]}
xgb_reg = XGBRegressor(n_estimators=1000, learning_rate=0.05, 
                       colsample_bytree=0.5, subsample=0.8)
best_xgb = print_best_params(xgb_reg, xgb_params)
# Out:
# XGBRegressor 5 CV 시 최적 평균 RMSE 값: 0.1217, 최적 alpha:{'n_estimators': 1000}

# %% [markdown]
# XGB는 하이퍼파라미터를 여러개 하기는 곤란하고 다만 그냥 EVAL만 한번 한다.

# %%
from lightgbm import LGBMRegressor

lgbm_params = {'n_estimators':[1000]}
lgbm_reg = LGBMRegressor(n_estimators=1000, learning_rate=0.05, num_leaves=4, 
                         subsample=0.6, colsample_bytree=0.4, reg_lambda=10, n_jobs=-1)
best_lgbm = print_best_params(lgbm_reg, lgbm_params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 from lightgbm import LGBMRegressor
#       3 lgbm_params = {'n_estimators':[1000]}
#       4 lgbm_reg = LGBMRegressor(n_estimators=1000, learning_rate=0.05, num_leaves=4,
#       5                          subsample=0.6, colsample_bytree=0.4, reg_lambda=10, n_jobs=-1)
#
# File ~\anaconda3\Lib\site-packages\lightgbm\__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File ~\anaconda3\Lib\site-packages\lightgbm\basic.py:20
#      17 import numpy as np
#      18 import scipy.sparse
# ---> 20 from .compat import PANDAS_INSTALLED, concat, dt_DataTable, is_dtype_sparse, pd_DataFrame, pd_Series
#      21 from .libpath import find_lib_path
#      23 ZERO_THRESHOLD = 1e-35
#
# File ~\anaconda3\Lib\site-packages\lightgbm\compat.py:130
#     128 from dask.array import from_delayed as dask_array_from_delayed
#     129 from dask.bag import from_delayed as dask_bag_from_delayed
# --> 130 from dask.dataframe import DataFrame as dask_DataFrame
#     131 from dask.dataframe import Series as dask_Series
#     132 from dask.distributed import Client, default_client, wait
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\__init__.py:6
#       4 import dask.dataframe._pyarrow_compat
#       5 from dask.base import compute
# ----> 6 from dask.dataframe import backends, dispatch, rolling
#       7 from dask.dataframe.core import (
#       8     DataFrame,
#       9     Index,
#    (...)
#      15     to_timedelta,
#      16 )
#      17 from dask.dataframe.groupby import Aggregation
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\backends.py:15
#      13 from dask.backends import CreationDispatch, DaskBackendEntrypoint
#      14 from dask.dataframe._compat import is_any_real_numeric_dtype
# ---> 15 from dask.dataframe.core import DataFrame, Index, Scalar, Series, _Frame
#      16 from dask.dataframe.dispatch import (
#      17     categorical_dtype_dispatch,
#      18     concat,
#    (...)
#      35     union_categoricals_dispatch,
#      36 )
#      37 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\core.py:36
#      34 from dask.blockwise import Blockwise, BlockwiseDep, BlockwiseDepDict, blockwise
#      35 from dask.context import globalmethod
# ---> 36 from dask.dataframe import methods
#      37 from dask.dataframe._compat import (
#      38     PANDAS_GE_140,
#      39     PANDAS_GE_150,
#    (...)
#      47     is_string_dtype,
#      48 )
#      49 from dask.dataframe.accessor import CachedAccessor, DatetimeAccessor, StringAccessor
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\methods.py:34
#      22 #  preserve compatibility while moving dispatch objects
#      23 from dask.dataframe.dispatch import (  # noqa: F401
#      24     concat,
#      25     concat_dispatch,
#    (...)
#      32     union_categoricals,
#      33 )
# ---> 34 from dask.dataframe.utils import is_dataframe_like, is_index_like, is_series_like
#      36 # cuDF may try to import old dispatch functions
#      37 hash_df = hash_object_dispatch
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\utils.py:20
#      18 from dask.base import get_scheduler, is_dask_collection
#      19 from dask.core import get_deps
# ---> 20 from dask.dataframe import (  # noqa: F401 register pandas extension types
#      21     _dtypes,
#      22     methods,
#      23 )
#      24 from dask.dataframe._compat import PANDAS_GE_150, tm  # noqa: F401
#      25 from dask.dataframe.dispatch import (  # noqa : F401
#      26     make_meta,
#      27     make_meta_obj,
#      28     meta_nonempty,
#      29 )
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\_dtypes.py:9
#       6 import pandas as pd
#       8 from dask.dataframe._compat import PANDAS_GE_150
# ----> 9 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#      12 @make_array_nonempty.register(pd.DatetimeTZDtype)
#      13 def _(dtype):
#      14     return pd.array([pd.Timestamp(1), pd.NaT], dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\extensions.py:8
#       1 """
#       2 Support for pandas ExtensionArray in dask.dataframe.
#       3
#       4 See :ref:`extensionarrays` for more.
#       5 """
#       6 from __future__ import annotations
# ----> 8 from dask.dataframe.accessor import (
#       9     register_dataframe_accessor,
#      10     register_index_accessor,
#      11     register_series_accessor,
#      12 )
#      13 from dask.utils import Dispatch
#      15 make_array_nonempty = Dispatch("make_array_nonempty")
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\accessor.py:126
#     113         token = f"{self._accessor_name}-{attr}"
#     114         return self._series.map_partitions(
#     115             self._delegate_method,
#     116             self._accessor_name,
#    (...)
#     122             token=token,
#     123         )
# --> 126 class DatetimeAccessor(Accessor):
#     127     """Accessor object for datetimelike properties of the Series values.
#     128
#     129     Examples
#    (...)
#     132     >>> s.dt.microsecond  # doctest: +SKIP
#     133     """
#     135     _accessor_name = "dt"
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\accessor.py:81, in Accessor.__init_subclass__(cls, **kwargs)
#      79 attr, min_version = item if isinstance(item, tuple) else (item, None)
#      80 if not hasattr(cls, attr):
# ---> 81     _bind_property(cls, pd_cls, attr, min_version)
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\accessor.py:35, in _bind_property(cls, pd_cls, attr, min_version)
#      33 except Exception:
#      34     pass
# ---> 35 setattr(cls, attr, property(derived_from(pd_cls, version=min_version)(func)))
#
# File ~\anaconda3\Lib\site-packages\dask\utils.py:856, in derived_from.<locals>.wrapper(method)
#     854 try:
#     855     extra = getattr(method, "__doc__", None) or ""
# --> 856     method.__doc__ = _derived_from(
#     857         original_klass,
#     858         method,
#     859         ua_args=ua_args,
#     860         extra=extra,
#     861         skipblocks=skipblocks,
#     862         inconsistencies=inconsistencies,
#     863     )
#     864     return method
#     866 except AttributeError:
#
# File ~\anaconda3\Lib\site-packages\dask\utils.py:809, in _derived_from(cls, method, ua_args, extra, skipblocks, inconsistencies)
#     807 # Mark unsupported arguments
#     808 try:
# --> 809     method_args = get_named_args(method)
#     810     original_args = get_named_args(original_method)
#     811     not_supported = [m for m in original_args if m not in method_args]
#
# File ~\anaconda3\Lib\site-packages\dask\utils.py:570, in get_named_args(func)
#     568 def get_named_args(func) -> list[str]:
#     569     """Get all non ``*args/**kwargs`` arguments for a function"""
# --> 570     s = inspect.signature(func)
#     571     return [
#     572         n
#     573         for n, p in s.parameters.items()
#     574         if p.kind in [p.POSITIONAL_OR_KEYWORD, p.POSITIONAL_ONLY, p.KEYWORD_ONLY]
#     575     ]
#
# File ~\anaconda3\Lib\inspect.py:3263, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3261 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3262     """Get a signature object for the passed callable."""
# -> 3263     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3264                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~\anaconda3\Lib\inspect.py:3011, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3007 @classmethod
#    3008 def from_callable(cls, obj, *,
#    3009                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3010     """Constructs Signature for the given callable object."""
# -> 3011     return _signature_from_callable(obj, sigcls=cls,
#    3012                                     follow_wrapper_chains=follow_wrapped,
#    3013                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~\anaconda3\Lib\inspect.py:2599, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2597     call = getattr_static(type(obj), '__call__', None)
#    2598     if call is not None:
# -> 2599         call = _descriptor_get(call, obj)
#    2600         return _get_signature_of(call)
#    2602 raise ValueError('callable {!r} is not supported by signature'.format(obj))
#
# File ~\anaconda3\Lib\inspect.py:2432, in _descriptor_get(descriptor, obj)
#    2430 if get is _sentinel:
#    2431     return descriptor
# -> 2432 return get(descriptor, obj, type(obj))
#
# TypeError: descriptor '__call__' for 'type' objects doesn't apply to a 'property' object

# %%
# 모델의 중요도 상위 20개의 피처명과 그때의 중요도값을 Series로 반환.
def get_top_features(model):
    ftr_importances_values = model.feature_importances_
    ftr_importances = pd.Series(ftr_importances_values, index=X_features.columns  )
    ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]
    return ftr_top20

def visualize_ftr_importances(models):
    # 2개 회귀 모델의 시각화를 위해 2개의 컬럼을 가지는 subplot 생성
    fig, axs = plt.subplots(figsize=(24,10),nrows=1, ncols=2)
    fig.tight_layout() 
    # 입력인자로 받은 list객체인 models에서 차례로 model을 추출하여 피처 중요도 시각화. 
    for i_num, model in enumerate(models):
        # 중요도 상위 20개의 피처명과 그때의 중요도값 추출 
        ftr_top20 = get_top_features(model)
        axs[i_num].set_title(model.__class__.__name__+' Feature Importances', size=25)
        #font 크기 조정.
        for label in (axs[i_num].get_xticklabels() + axs[i_num].get_yticklabels()):
            label.set_fontsize(22)
        sns.barplot(x=ftr_top20.values, y=ftr_top20.index , ax=axs[i_num])

# 앞 예제에서 print_best_params( )가 반환한 GridSearchCV로 최적화된 모델의 피처 중요도 시각화    
models = [best_xgb]
visualize_ftr_importances(models)

# %% [markdown]
# ### **Ridge + Lasso Conversion Model**

# %% [markdown]
# 칵테일을 제조하듯 가중치를 두고 평균을 낸다.

# %%
def get_rmse_pred(preds):
    for key in preds.keys():
        pred_value = preds[key]
        mse = mean_squared_error(y_test , pred_value)
        rmse = np.sqrt(mse)
        print('{0} 모델의 RMSE: {1}'.format(key, rmse))

# 개별 모델의 학습
ridge_reg = Ridge(alpha=8)
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)
# 개별 모델 예측
ridge_pred = ridge_reg.predict(X_test)
lasso_pred = lasso_reg.predict(X_test)

# 개별 모델 예측값 혼합으로 최종 예측값 도출
pred = 0.4 * ridge_pred + 0.6 * lasso_pred #(가중치는 합쳐서 1이 되어야 한다. 가중치는 실험적으로 결정)
preds = {'최종 혼합': pred,
         'Ridge': ridge_pred,
         'Lasso': lasso_pred}
#최종 혼합 모델, 개별모델의 RMSE 값 출력
get_rmse_pred(preds)
# Out:
# 최종 혼합 모델의 RMSE: 0.10003918046509158
# Ridge 모델의 RMSE: 0.10333427903129075
# Lasso 모델의 RMSE: 0.10023723657391555

# %%
'''
xgb_reg = XGBRegressor(n_estimators=1000, learning_rate=0.05, 
                       colsample_bytree=0.5, subsample=0.8)
lgbm_reg = LGBMRegressor(n_estimators=1000, learning_rate=0.05, num_leaves=4, 
                         subsample=0.6, colsample_bytree=0.4, reg_lambda=10, n_jobs=-1)
xgb_reg.fit(X_train, y_train)
lgbm_reg.fit(X_train, y_train)
xgb_pred = xgb_reg.predict(X_test)
lgbm_pred = lgbm_reg.predict(X_test)

pred = 0.5 * xgb_pred + 0.5 * lgbm_pred
preds = {'최종 혼합': pred,
         'XGBM': xgb_pred,
         'LGBM': lgbm_pred}
        
get_rmse_pred(preds)
'''
# Out:
# "\nxgb_reg = XGBRegressor(n_estimators=1000, learning_rate=0.05, \n                       colsample_bytree=0.5, subsample=0.8)\nlgbm_reg = LGBMRegressor(n_estimators=1000, learning_rate=0.05, num_leaves=4, \n                         subsample=0.6, colsample_bytree=0.4, reg_lambda=10, n_jobs=-1)\nxgb_reg.fit(X_train, y_train)\nlgbm_reg.fit(X_train, y_train)\nxgb_pred = xgb_reg.predict(X_test)\nlgbm_pred = lgbm_reg.predict(X_test)\n\npred = 0.5 * xgb_pred + 0.5 * lgbm_pred\npreds = {'최종 혼합': pred,\n         'XGBM': xgb_pred,\n         'LGBM': lgbm_pred}\n        \nget_rmse_pred(preds)\n"

# %% [markdown]
# ### **Regressor with Stacking**

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

# 개별 기반 모델에서 최종 메타 모델이 사용할 학습 및 테스트용 데이터를 생성하기 위한 함수. 
def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n, n_folds ):
    # 지정된 n_folds값으로 KFold 생성.
    kf = KFold(n_splits=n_folds, shuffle=False)
    #추후에 메타 모델이 사용할 학습 데이터 반환을 위한 넘파이 배열 초기화 
    train_fold_pred = np.zeros((X_train_n.shape[0] ,1 ))
    test_pred = np.zeros((X_test_n.shape[0],n_folds))
    print(model.__class__.__name__ , ' model 시작 ')
    
    for folder_counter , (train_index, valid_index) in enumerate(kf.split(X_train_n)):
        #입력된 학습 데이터에서 기반 모델이 학습/예측할 폴드 데이터 셋 추출 
        print('\t 폴드 세트: ',folder_counter,' 시작 ')
        X_tr = X_train_n[train_index] 
        y_tr = y_train_n[train_index] 
        X_te = X_train_n[valid_index]  
        
        #폴드 세트 내부에서 다시 만들어진 학습 데이터로 기반 모델의 학습 수행.
        model.fit(X_tr , y_tr)       
        #폴드 세트 내부에서 다시 만들어진 검증 데이터로 기반 모델 예측 후 데이터 저장.
        train_fold_pred[valid_index, :] = model.predict(X_te).reshape(-1,1)
        #입력된 원본 테스트 데이터를 폴드 세트내 학습된 기반 모델에서 예측 후 데이터 저장. 
        test_pred[:, folder_counter] = model.predict(X_test_n)
            
    # 폴드 세트 내에서 원본 테스트 데이터를 예측한 데이터를 평균하여 테스트 데이터로 생성 
    test_pred_mean = np.mean(test_pred, axis=1).reshape(-1,1)    
    
    #train_fold_pred는 최종 메타 모델이 사용하는 학습 데이터, test_pred_mean은 테스트 데이터
    return train_fold_pred , test_pred_mean

# %%
# get_stacking_base_datasets( )은 넘파이 ndarray를 인자로 사용하므로 DataFrame을 넘파이로 변환. 
X_train_n = X_train.values
X_test_n = X_test.values
y_train_n = y_train.values

# 각 개별 기반(Base)모델이 생성한 학습용/테스트용 데이터 반환. (각 train이 메타 모델이 사용할 데이터)
ridge_train, ridge_test = get_stacking_base_datasets(ridge_reg, X_train_n, y_train_n, X_test_n, 5)
lasso_train, lasso_test = get_stacking_base_datasets(lasso_reg, X_train_n, y_train_n, X_test_n, 5)
xgb_train, xgb_test = get_stacking_base_datasets(xgb_reg, X_train_n, y_train_n, X_test_n, 5)  
#lgbm_train, lgbm_test = get_stacking_base_datasets(lgbm_reg, X_train_n, y_train_n, X_test_n, 5)
# Out:
# Ridge  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# Lasso  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# XGBRegressor  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작

# %%
ridge_train
# Out:
# array([[12.74416323],
#        [12.1339316 ],
#        [11.46712929],
#        ...,
#        [11.15603143],
#        [12.15518682],
#        [11.90899928]])

# %%
# 개별 모델이 반환한 학습 및 테스트용 데이터 세트를 Stacking 형태로 결합.  
# 마치 볏집을 쌓아올리듯
Stack_final_X_train = np.concatenate((ridge_train, lasso_train, 
                                      xgb_train), axis=1)
Stack_final_X_test = np.concatenate((ridge_test, lasso_test, 
                                     xgb_test), axis=1)

# 최종 메타 모델은 라쏘 모델을 적용. 
meta_model_lasso = Lasso(alpha=0.0005)

#기반 모델의 예측값을 기반으로 새롭게 만들어진 학습 및 테스트용 데이터로 예측하고 RMSE 측정.
meta_model_lasso.fit(Stack_final_X_train, y_train)
final = meta_model_lasso.predict(Stack_final_X_test)
mse = mean_squared_error(y_test , final)
rmse = np.sqrt(mse)
print('스태킹 회귀 모델의 최종 RMSE 값은:', rmse)
# Out:
# 스태킹 회귀 모델의 최종 RMSE 값은: 0.09682558392963349

# %% [markdown]
# 스태킹이 회귀에서 꽤 쓸만하다
